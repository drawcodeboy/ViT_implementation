# %%
import sys

# %%
sys.path.append('G:\\Doby\\ViT')
print(sys.path)
# Out:
# ['G:\\Doby\\ViT\\models', 'C:\\Users\\user\\anaconda3\\python310.zip', 'C:\\Users\\user\\anaconda3\\DLLs', 'C:\\Users\\user\\anaconda3\\lib', 'C:\\Users\\user\\anaconda3', '', 'C:\\Users\\user\\anaconda3\\lib\\site-packages', 'C:\\Users\\user\\anaconda3\\lib\\site-packages\\win32', 'C:\\Users\\user\\anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\Users\\user\\anaconda3\\lib\\site-packages\\Pythonwin', 'G:\\Doby\\ViT']

# %%
import torch
from torch import nn
from torchinfo import summary
from models.embedding.patch_embedding import PatchEmbedding
from models.embedding.input_embedding import InputEmbedding
from models.transformer_encoder.transformer_encoder import TransformerEncoder

# %%
class ViT(nn.Module):
    def __init__(self, channel, img_size, patch_size, d_dim, qkv_dim, att_head_num, mlp_hidden_dim, n_transform_layers, mlp_head_hidden_dim, n_classes):
        '''
        channel : 입력 이미지 Channel
        img_size : 입력 이미지 Height or Width
        patch_size : 나눌 Patch의 사이즈
        d_dim : embedding을 Linear Projection 했을 때, Dimension
        qkv_dim : attention 할 때, QKV Matrix의 Col 값 (d_dim과 동일하게 해야하는 것으로 추측)
        att_head_num : 몇 번의 attention을 가지고 Multi-Head를 할 것인가
        mlp_hidden_dim : transformer encoder의 MLP에 사용되는 Hidden Layer의 Dimension
        n_transform_layers : transformer encoder 수
        mlp_head_hidden_dim : MLP Head의 Hidden Layer Dimension
        n_classes : 분류하고자 하는 class의 수
        '''
        super().__init__()
        self.embedding_size = ((img_size*img_size)/(patch_size*patch_size))+1

        self.embedding = InputEmbedding(channel, img_size, patch_size, d_dim)
        self.layers = nn.ModuleList([TransformerEncoder(self.embedding_size, 
                                                        d_dim, 
                                                        qkv_dim, 
                                                        att_head_num, 
                                                        mlp_hidden_dim) for _ in range(n_transform_layers)])
        self.MLP_Head = nn.Sequential(nn.Linear(qkv_dim, mlp_head_hidden_dim),
                                      nn.GELU(),
                                      nn.Linear(mlp_head_hidden_dim, n_classes))
        if n_classes == 2:
            self.acti = nn.Sigmoid()
        else:
            self.acti = nn.Softmax(dim=-1)

    def forward(self, x):
        print(f'input shape\n{x.shape}\n')
        
        x = self.embedding(x)
        print(f'after embedding shape\n{x.shape}\n')
        
        for transformer in self.layers:
            x = transformer(x)
        print(f'after transformer shape\n{x.shape}\n')
        
        x = x[:, 0, :]
        print(f'z_0^L shape\n{x.shape}\n')
        
        x = self.MLP_Head(x)
        print(f'last MLP Head for Classification shape\n{x.shape}\n')
        
        return x

# %%
vit = ViT(channel=3, 
          img_size=224, 
          patch_size=16, 
          d_dim=10, 
          qkv_dim=10, 
          att_head_num=8, 
          mlp_hidden_dim=20, 
          n_transform_layers=6, 
          mlp_head_hidden_dim=30, 
          n_classes=10)

# %%
summary(vit, (2, 3, 224, 224))
# Out:
# input shape
# torch.Size([2, 3, 224, 224])
#
# after embedding shape
# torch.Size([2, 197, 10])
#
# after transformer shape
# torch.Size([2, 197, 10])
#
# z_0^L shape
# torch.Size([2, 10])
#
# last MLP Head for Classification shape
# torch.Size([2, 10])
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ViT                                           [2, 10]                   --
# ├─InputEmbedding: 1-1                         [2, 197, 10]              1,980
# │    └─PatchEmbedding: 2-1                    [2, 196, 10]              --
# │    │    └─Flatten: 3-1                      [2, 768]                  --
# │    │    └─Flatten: 3-2                      [2, 768]                  --
# │    │    └─Flatten: 3-3                      [2, 768]                  --
# │    │    └─Flatten: 3-4                      [2, 768]                  --
# │    │    └─Flatten: 3-5                      [2, 768]                  --
# │    │    └─Flatten: 3-6                      [2, 768]                  --
# │    │    └─Flatten: 3-7                      [2, 768]                  --
# │    │    └─Flatten: 3-8                      [2, 768]                  --
# │    │    └─Flatten: 3-9                      [2, 768]                  --
# │    │    └─Flatten: 3-10                     [2, 768]                  --
# │    │    └─Flatten: 3-11                     [2, 768]                  --
# │    │    └─Flatten: 3-12                     [2, 768]                  --
# │    │    └─Flatten: 3-13                     [2, 768]                  --
# │    │    └─Flatten: 3-14                     [2, 768]                  --
# │    │    └─Flatten: 3-15                     [2, 768]                  --
# │    │    └─Flatten: 3-16                     [2, 768]                  --
# │    │    └─Flatten: 3-17                     [2, 768]                  --
# │    │    └─Flatten: 3-18                     [2, 768]                  --
# │    │    └─Flatten: 3-19                     [2, 768]                  --
# │    │    └─Flatten: 3-20                     [2, 768]                  --
# │    │    └─Flatten: 3-21                     [2, 768]                  --
# │    │    └─Flatten: 3-22                     [2, 768]                  --
# │    │    └─Flatten: 3-23                     [2, 768]                  --
# │    │    └─Flatten: 3-24                     [2, 768]                  --
# │    │    └─Flatten: 3-25                     [2, 768]                  --
# │    │    └─Flatten: 3-26                     [2, 768]                  --
# │    │    └─Flatten: 3-27                     [2, 768]                  --
# │    │    └─Flatten: 3-28                     [2, 768]                  --
# │    │    └─Flatten: 3-29                     [2, 768]                  --
# │    │    └─Flatten: 3-30                     [2, 768]                  --
# │    │    └─Flatten: 3-31                     [2, 768]                  --
# │    │    └─Flatten: 3-32                     [2, 768]                  --
# │    │    └─Flatten: 3-33                     [2, 768]                  --
# │    │    └─Flatten: 3-34                     [2, 768]                  --
# │    │    └─Flatten: 3-35                     [2, 768]                  --
# │    │    └─Flatten: 3-36                     [2, 768]                  --
# │    │    └─Flatten: 3-37                     [2, 768]                  --
# │    │    └─Flatten: 3-38                     [2, 768]                  --
# │    │    └─Flatten: 3-39                     [2, 768]                  --
# │    │    └─Flatten: 3-40                     [2, 768]                  --
# │    │    └─Flatten: 3-41                     [2, 768]                  --
# │    │    └─Flatten: 3-42                     [2, 768]                  --
# │    │    └─Flatten: 3-43                     [2, 768]                  --
# │    │    └─Flatten: 3-44                     [2, 768]                  --
# │    │    └─Flatten: 3-45                     [2, 768]                  --
# │    │    └─Flatten: 3-46                     [2, 768]                  --
# │    │    └─Flatten: 3-47                     [2, 768]                  --
# │    │    └─Flatten: 3-48                     [2, 768]                  --
# │    │    └─Flatten: 3-49                     [2, 768]                  --
# │    │    └─Flatten: 3-50                     [2, 768]                  --
# │    │    └─Flatten: 3-51                     [2, 768]                  --
# │    │    └─Flatten: 3-52                     [2, 768]                  --
# │    │    └─Flatten: 3-53                     [2, 768]                  --
# │    │    └─Flatten: 3-54                     [2, 768]                  --
# │    │    └─Flatten: 3-55                     [2, 768]                  --
# │    │    └─Flatten: 3-56                     [2, 768]                  --
# │    │    └─Flatten: 3-57                     [2, 768]                  --
# │    │    └─Flatten: 3-58                     [2, 768]                  --
# │    │    └─Flatten: 3-59                     [2, 768]                  --
# │    │    └─Flatten: 3-60                     [2, 768]                  --
# │    │    └─Flatten: 3-61                     [2, 768]                  --
# │    │    └─Flatten: 3-62                     [2, 768]                  --
# │    │    └─Flatten: 3-63                     [2, 768]                  --
# │    │    └─Flatten: 3-64                     [2, 768]                  --
# │    │    └─Flatten: 3-65                     [2, 768]                  --
# │    │    └─Flatten: 3-66                     [2, 768]                  --
# │    │    └─Flatten: 3-67                     [2, 768]                  --
# │    │    └─Flatten: 3-68                     [2, 768]                  --
# │    │    └─Flatten: 3-69                     [2, 768]                  --
# │    │    └─Flatten: 3-70                     [2, 768]                  --
# │    │    └─Flatten: 3-71                     [2, 768]                  --
# │    │    └─Flatten: 3-72                     [2, 768]                  --
# │    │    └─Flatten: 3-73                     [2, 768]                  --
# │    │    └─Flatten: 3-74                     [2, 768]                  --
# │    │    └─Flatten: 3-75                     [2, 768]                  --
# │    │    └─Flatten: 3-76                     [2, 768]                  --
# │    │    └─Flatten: 3-77                     [2, 768]                  --
# │    │    └─Flatten: 3-78                     [2, 768]                  --
# │    │    └─Flatten: 3-79                     [2, 768]                  --
# │    │    └─Flatten: 3-80                     [2, 768]                  --
# │    │    └─Flatten: 3-81                     [2, 768]                  --
# │    │    └─Flatten: 3-82                     [2, 768]                  --
# │    │    └─Flatten: 3-83                     [2, 768]                  --
# │    │    └─Flatten: 3-84                     [2, 768]                  --
# │    │    └─Flatten: 3-85                     [2, 768]                  --
# │    │    └─Flatten: 3-86                     [2, 768]                  --
# │    │    └─Flatten: 3-87                     [2, 768]                  --
# │    │    └─Flatten: 3-88                     [2, 768]                  --
# │    │    └─Flatten: 3-89                     [2, 768]                  --
# │    │    └─Flatten: 3-90                     [2, 768]                  --
# │    │    └─Flatten: 3-91                     [2, 768]                  --
# │    │    └─Flatten: 3-92                     [2, 768]                  --
# │    │    └─Flatten: 3-93                     [2, 768]                  --
# │    │    └─Flatten: 3-94                     [2, 768]                  --
# │    │    └─Flatten: 3-95                     [2, 768]                  --
# │    │    └─Flatten: 3-96                     [2, 768]                  --
# │    │    └─Flatten: 3-97                     [2, 768]                  --
# │    │    └─Flatten: 3-98                     [2, 768]                  --
# │    │    └─Flatten: 3-99                     [2, 768]                  --
# │    │    └─Flatten: 3-100                    [2, 768]                  --
# │    │    └─Flatten: 3-101                    [2, 768]                  --
# │    │    └─Flatten: 3-102                    [2, 768]                  --
# │    │    └─Flatten: 3-103                    [2, 768]                  --
# │    │    └─Flatten: 3-104                    [2, 768]                  --
# │    │    └─Flatten: 3-105                    [2, 768]                  --
# │    │    └─Flatten: 3-106                    [2, 768]                  --
# │    │    └─Flatten: 3-107                    [2, 768]                  --
# │    │    └─Flatten: 3-108                    [2, 768]                  --
# │    │    └─Flatten: 3-109                    [2, 768]                  --
# │    │    └─Flatten: 3-110                    [2, 768]                  --
# │    │    └─Flatten: 3-111                    [2, 768]                  --
# │    │    └─Flatten: 3-112                    [2, 768]                  --
# │    │    └─Flatten: 3-113                    [2, 768]                  --
# │    │    └─Flatten: 3-114                    [2, 768]                  --
# │    │    └─Flatten: 3-115                    [2, 768]                  --
# │    │    └─Flatten: 3-116                    [2, 768]                  --
# │    │    └─Flatten: 3-117                    [2, 768]                  --
# │    │    └─Flatten: 3-118                    [2, 768]                  --
# │    │    └─Flatten: 3-119                    [2, 768]                  --
# │    │    └─Flatten: 3-120                    [2, 768]                  --
# │    │    └─Flatten: 3-121                    [2, 768]                  --
# │    │    └─Flatten: 3-122                    [2, 768]                  --
# │    │    └─Flatten: 3-123                    [2, 768]                  --
# │    │    └─Flatten: 3-124                    [2, 768]                  --
# │    │    └─Flatten: 3-125                    [2, 768]                  --
# │    │    └─Flatten: 3-126                    [2, 768]                  --
# │    │    └─Flatten: 3-127                    [2, 768]                  --
# │    │    └─Flatten: 3-128                    [2, 768]                  --
# │    │    └─Flatten: 3-129                    [2, 768]                  --
# │    │    └─Flatten: 3-130                    [2, 768]                  --
# │    │    └─Flatten: 3-131                    [2, 768]                  --
# │    │    └─Flatten: 3-132                    [2, 768]                  --
# │    │    └─Flatten: 3-133                    [2, 768]                  --
# │    │    └─Flatten: 3-134                    [2, 768]                  --
# │    │    └─Flatten: 3-135                    [2, 768]                  --
# │    │    └─Flatten: 3-136                    [2, 768]                  --
# │    │    └─Flatten: 3-137                    [2, 768]                  --
# │    │    └─Flatten: 3-138                    [2, 768]                  --
# │    │    └─Flatten: 3-139                    [2, 768]                  --
# │    │    └─Flatten: 3-140                    [2, 768]                  --
# │    │    └─Flatten: 3-141                    [2, 768]                  --
# │    │    └─Flatten: 3-142                    [2, 768]                  --
# │    │    └─Flatten: 3-143                    [2, 768]                  --
# │    │    └─Flatten: 3-144                    [2, 768]                  --
# │    │    └─Flatten: 3-145                    [2, 768]                  --
# │    │    └─Flatten: 3-146                    [2, 768]                  --
# │    │    └─Flatten: 3-147                    [2, 768]                  --
# │    │    └─Flatten: 3-148                    [2, 768]                  --
# │    │    └─Flatten: 3-149                    [2, 768]                  --
# │    │    └─Flatten: 3-150                    [2, 768]                  --
# │    │    └─Flatten: 3-151                    [2, 768]                  --
# │    │    └─Flatten: 3-152                    [2, 768]                  --
# │    │    └─Flatten: 3-153                    [2, 768]                  --
# │    │    └─Flatten: 3-154                    [2, 768]                  --
# │    │    └─Flatten: 3-155                    [2, 768]                  --
# │    │    └─Flatten: 3-156                    [2, 768]                  --
# │    │    └─Flatten: 3-157                    [2, 768]                  --
# │    │    └─Flatten: 3-158                    [2, 768]                  --
# │    │    └─Flatten: 3-159                    [2, 768]                  --
# │    │    └─Flatten: 3-160                    [2, 768]                  --
# │    │    └─Flatten: 3-161                    [2, 768]                  --
# │    │    └─Flatten: 3-162                    [2, 768]                  --
# │    │    └─Flatten: 3-163                    [2, 768]                  --
# │    │    └─Flatten: 3-164                    [2, 768]                  --
# │    │    └─Flatten: 3-165                    [2, 768]                  --
# │    │    └─Flatten: 3-166                    [2, 768]                  --
# │    │    └─Flatten: 3-167                    [2, 768]                  --
# │    │    └─Flatten: 3-168                    [2, 768]                  --
# │    │    └─Flatten: 3-169                    [2, 768]                  --
# │    │    └─Flatten: 3-170                    [2, 768]                  --
# │    │    └─Flatten: 3-171                    [2, 768]                  --
# │    │    └─Flatten: 3-172                    [2, 768]                  --
# │    │    └─Flatten: 3-173                    [2, 768]                  --
# │    │    └─Flatten: 3-174                    [2, 768]                  --
# │    │    └─Flatten: 3-175                    [2, 768]                  --
# │    │    └─Flatten: 3-176                    [2, 768]                  --
# │    │    └─Flatten: 3-177                    [2, 768]                  --
# │    │    └─Flatten: 3-178                    [2, 768]                  --
# │    │    └─Flatten: 3-179                    [2, 768]                  --
# │    │    └─Flatten: 3-180                    [2, 768]                  --
# │    │    └─Flatten: 3-181                    [2, 768]                  --
# │    │    └─Flatten: 3-182                    [2, 768]                  --
# │    │    └─Flatten: 3-183                    [2, 768]                  --
# │    │    └─Flatten: 3-184                    [2, 768]                  --
# │    │    └─Flatten: 3-185                    [2, 768]                  --
# │    │    └─Flatten: 3-186                    [2, 768]                  --
# │    │    └─Flatten: 3-187                    [2, 768]                  --
# │    │    └─Flatten: 3-188                    [2, 768]                  --
# │    │    └─Flatten: 3-189                    [2, 768]                  --
# │    │    └─Flatten: 3-190                    [2, 768]                  --
# │    │    └─Flatten: 3-191                    [2, 768]                  --
# │    │    └─Flatten: 3-192                    [2, 768]                  --
# │    │    └─Flatten: 3-193                    [2, 768]                  --
# │    │    └─Flatten: 3-194                    [2, 768]                  --
# │    │    └─Flatten: 3-195                    [2, 768]                  --
# │    │    └─Flatten: 3-196                    [2, 768]                  --
# │    │    └─ModuleList: 3-197                 --                        1,507,240
# ├─ModuleList: 1-2                             --                        --
# │    └─TransformerEncoder: 2-2                [2, 197, 10]              --
# │    │    └─LayerNorm: 3-198                  [2, 197, 10]              20
# │    │    └─MultiHeadAttention: 3-199         [2, 197, 10]              800
# │    │    └─LayerNorm: 3-200                  [2, 197, 10]              20
# │    │    └─Sequential: 3-201                 [2, 197, 10]              430
# │    └─TransformerEncoder: 2-3                [2, 197, 10]              --
# │    │    └─LayerNorm: 3-202                  [2, 197, 10]              20
# │    │    └─MultiHeadAttention: 3-203         [2, 197, 10]              800
# │    │    └─LayerNorm: 3-204                  [2, 197, 10]              20
# │    │    └─Sequential: 3-205                 [2, 197, 10]              430
# │    └─TransformerEncoder: 2-4                [2, 197, 10]              --
# │    │    └─LayerNorm: 3-206                  [2, 197, 10]              20
# │    │    └─MultiHeadAttention: 3-207         [2, 197, 10]              800
# │    │    └─LayerNorm: 3-208                  [2, 197, 10]              20
# │    │    └─Sequential: 3-209                 [2, 197, 10]              430
# │    └─TransformerEncoder: 2-5                [2, 197, 10]              --
# │    │    └─LayerNorm: 3-210                  [2, 197, 10]              20
# │    │    └─MultiHeadAttention: 3-211         [2, 197, 10]              800
# │    │    └─LayerNorm: 3-212                  [2, 197, 10]              20
# │    │    └─Sequential: 3-213                 [2, 197, 10]              430
# │    └─TransformerEncoder: 2-6                [2, 197, 10]              --
# │    │    └─LayerNorm: 3-214                  [2, 197, 10]              20
# │    │    └─MultiHeadAttention: 3-215         [2, 197, 10]              800
# │    │    └─LayerNorm: 3-216                  [2, 197, 10]              20
# │    │    └─Sequential: 3-217                 [2, 197, 10]              430
# │    └─TransformerEncoder: 2-7                [2, 197, 10]              --
# │    │    └─LayerNorm: 3-218                  [2, 197, 10]              20
# │    │    └─MultiHeadAttention: 3-219         [2, 197, 10]              800
# │    │    └─LayerNorm: 3-220                  [2, 197, 10]              20
# │    │    └─Sequential: 3-221                 [2, 197, 10]              430
# ├─Sequential: 1-3                             [2, 10]                   --
# │    └─Linear: 2-8                            [2, 30]                   330
# │    └─GELU: 2-9                              [2, 30]                   --
# │    └─Linear: 2-10                           [2, 10]                   310
# ===============================================================================================
# Total params: 1,517,480
# Trainable params: 1,517,480
# Non-trainable params: 0
# Total mult-adds (M): 3.02
# ===============================================================================================
# Input size (MB): 1.20
# Forward/backward pass size (MB): 1.17
# Params size (MB): 6.06
# Estimated Total Size (MB): 8.43
# ===============================================================================================
