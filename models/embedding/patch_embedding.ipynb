# %%
import torch
from torch import nn
from torchsummary import summary
import math

# %%
class PatchEmbedding(nn.Module):
    def __init__(self, channel, img_size, patch_size, d_dim):
        super().__init__()
        # img_size: 정사각 이미지인 것으로 정한다
        # patch_size: 원하는 patch size
        # d_dim: Linear Projection을 했을 때, 원하는 차원의 크기

        self.img_size = img_size
        self.channel = channel
            
        self.patch_size = patch_size
        
        self.n_patches = int((img_size * img_size) / (patch_size * patch_size))
        self.flatten = nn.Flatten(start_dim=1, end_dim=-1)
        
        self.linear_projs = nn.ModuleList([nn.Linear(patch_size*patch_size*channel, d_dim) for _ in range(self.n_patches)])

    def crop_img(self, x):
        patches = []
        row = int(math.sqrt(self.n_patches))
        col = int(math.sqrt(self.n_patches))
        p_len = self.patch_size
        
        
        for i in range(row):
            for j in range(col):
                temp = x[:, :, i*p_len:(i+1)*p_len, j*p_len:(j+1)*p_len]
                patches.append(temp)
                # one patch에 대한 시작점 (y, x)와 끝점 (y, x) 조사
                # print(f'{i*p_len} {(i+1)*p_len} {j*p_len} {(j+1)*p_len}')
                
        return patches
        
    def forward(self, x):
        # Patch 생성
        patches = self.crop_img(x)

        # Flatten
        patches_flatten = [self.flatten(patches[i]).unsqueeze(dim=-2) for i in range(self.n_patches)]
        print(patches[0].shape)
        print(patches_flatten[0].shape)

        # Linear Projection
        embedding_li = [self.linear_projs[i](patches_flatten[i]) for i in range(self.n_patches)]
        print(embedding_li[0].shape)

        # 모든 embedding concatenate
        embeddings = torch.concat(embedding_li, dim=-2)
        print(embeddings.shape)

        return embeddings

# %%
patch_embedding = PatchEmbedding(channel=3, img_size=224, patch_size=16, d_dim=30)

# %%
BATCH_SIZE = 16
summary(patch_embedding, (3, 224, 224), batch_size=-1)
# Out:
# torch.Size([2, 3, 16, 16])
# torch.Size([2, 1, 768])
# torch.Size([2, 1, 30])
# torch.Size([2, 196, 30])
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 768]               0
#            Flatten-2                  [-1, 768]               0
#            Flatten-3                  [-1, 768]               0
#            Flatten-4                  [-1, 768]               0
#            Flatten-5                  [-1, 768]               0
#            Flatten-6                  [-1, 768]               0
#            Flatten-7                  [-1, 768]               0
#            Flatten-8                  [-1, 768]               0
#            Flatten-9                  [-1, 768]               0
#           Flatten-10                  [-1, 768]               0
#           Flatten-11                  [-1, 768]               0
#           Flatten-12                  [-1, 768]               0
#           Flatten-13                  [-1, 768]               0
#           Flatten-14                  [-1, 768]               0
#           Flatten-15                  [-1, 768]               0
#           Flatten-16                  [-1, 768]               0
#           Flatten-17                  [-1, 768]               0
#           Flatten-18                  [-1, 768]               0
#           Flatten-19                  [-1, 768]               0
#           Flatten-20                  [-1, 768]               0
#           Flatten-21                  [-1, 768]               0
#           Flatten-22                  [-1, 768]               0
#           Flatten-23                  [-1, 768]               0
#           Flatten-24                  [-1, 768]               0
#           Flatten-25                  [-1, 768]               0
#           Flatten-26                  [-1, 768]               0
#           Flatten-27                  [-1, 768]               0
#           Flatten-28                  [-1, 768]               0
#           Flatten-29                  [-1, 768]               0
#           Flatten-30                  [-1, 768]               0
#           Flatten-31                  [-1, 768]               0
#           Flatten-32                  [-1, 768]               0
#           Flatten-33                  [-1, 768]               0
#           Flatten-34                  [-1, 768]               0
#           Flatten-35                  [-1, 768]               0
#           Flatten-36                  [-1, 768]               0
#           Flatten-37                  [-1, 768]               0
#           Flatten-38                  [-1, 768]               0
#           Flatten-39                  [-1, 768]               0
#           Flatten-40                  [-1, 768]               0
#           Flatten-41                  [-1, 768]               0
#           Flatten-42                  [-1, 768]               0
#           Flatten-43                  [-1, 768]               0
#           Flatten-44                  [-1, 768]               0
#           Flatten-45                  [-1, 768]               0
#           Flatten-46                  [-1, 768]               0
#           Flatten-47                  [-1, 768]               0
#           Flatten-48                  [-1, 768]               0
#           Flatten-49                  [-1, 768]               0
#           Flatten-50                  [-1, 768]               0
#           Flatten-51                  [-1, 768]               0
#           Flatten-52                  [-1, 768]               0
#           Flatten-53                  [-1, 768]               0
#           Flatten-54                  [-1, 768]               0
#           Flatten-55                  [-1, 768]               0
#           Flatten-56                  [-1, 768]               0
#           Flatten-57                  [-1, 768]               0
#           Flatten-58                  [-1, 768]               0
#           Flatten-59                  [-1, 768]               0
#           Flatten-60                  [-1, 768]               0
#           Flatten-61                  [-1, 768]               0
#           Flatten-62                  [-1, 768]               0
#           Flatten-63                  [-1, 768]               0
#           Flatten-64                  [-1, 768]               0
#           Flatten-65                  [-1, 768]               0
#           Flatten-66                  [-1, 768]               0
#           Flatten-67                  [-1, 768]               0
#           Flatten-68                  [-1, 768]               0
#           Flatten-69                  [-1, 768]               0
#           Flatten-70                  [-1, 768]               0
#           Flatten-71                  [-1, 768]               0
#           Flatten-72                  [-1, 768]               0
#           Flatten-73                  [-1, 768]               0
#           Flatten-74                  [-1, 768]               0
#           Flatten-75                  [-1, 768]               0
#           Flatten-76                  [-1, 768]               0
#           Flatten-77                  [-1, 768]               0
#           Flatten-78                  [-1, 768]               0
#           Flatten-79                  [-1, 768]               0
#           Flatten-80                  [-1, 768]               0
#           Flatten-81                  [-1, 768]               0
#           Flatten-82                  [-1, 768]               0
#           Flatten-83                  [-1, 768]               0
#           Flatten-84                  [-1, 768]               0
#           Flatten-85                  [-1, 768]               0
#           Flatten-86                  [-1, 768]               0
#           Flatten-87                  [-1, 768]               0
#           Flatten-88                  [-1, 768]               0
#           Flatten-89                  [-1, 768]               0
#           Flatten-90                  [-1, 768]               0
#           Flatten-91                  [-1, 768]               0
#           Flatten-92                  [-1, 768]               0
#           Flatten-93                  [-1, 768]               0
#           Flatten-94                  [-1, 768]               0
#           Flatten-95                  [-1, 768]               0
#           Flatten-96                  [-1, 768]               0
#           Flatten-97                  [-1, 768]               0
#           Flatten-98                  [-1, 768]               0
#           Flatten-99                  [-1, 768]               0
#          Flatten-100                  [-1, 768]               0
#          Flatten-101                  [-1, 768]               0
#          Flatten-102                  [-1, 768]               0
#          Flatten-103                  [-1, 768]               0
#          Flatten-104                  [-1, 768]               0
#          Flatten-105                  [-1, 768]               0
#          Flatten-106                  [-1, 768]               0
#          Flatten-107                  [-1, 768]               0
#          Flatten-108                  [-1, 768]               0
#          Flatten-109                  [-1, 768]               0
#          Flatten-110                  [-1, 768]               0
#          Flatten-111                  [-1, 768]               0
#          Flatten-112                  [-1, 768]               0
#          Flatten-113                  [-1, 768]               0
#          Flatten-114                  [-1, 768]               0
#          Flatten-115                  [-1, 768]               0
#          Flatten-116                  [-1, 768]               0
#          Flatten-117                  [-1, 768]               0
#          Flatten-118                  [-1, 768]               0
#          Flatten-119                  [-1, 768]               0
#          Flatten-120                  [-1, 768]               0
#          Flatten-121                  [-1, 768]               0
#          Flatten-122                  [-1, 768]               0
#          Flatten-123                  [-1, 768]               0
#          Flatten-124                  [-1, 768]               0
#          Flatten-125                  [-1, 768]               0
#          Flatten-126                  [-1, 768]               0
#          Flatten-127                  [-1, 768]               0
#          Flatten-128                  [-1, 768]               0
#          Flatten-129                  [-1, 768]               0
#          Flatten-130                  [-1, 768]               0
#          Flatten-131                  [-1, 768]               0
#          Flatten-132                  [-1, 768]               0
#          Flatten-133                  [-1, 768]               0
#          Flatten-134                  [-1, 768]               0
#          Flatten-135                  [-1, 768]               0
#          Flatten-136                  [-1, 768]               0
#          Flatten-137                  [-1, 768]               0
#          Flatten-138                  [-1, 768]               0
#          Flatten-139                  [-1, 768]               0
#          Flatten-140                  [-1, 768]               0
#          Flatten-141                  [-1, 768]               0
#          Flatten-142                  [-1, 768]               0
#          Flatten-143                  [-1, 768]               0
#          Flatten-144                  [-1, 768]               0
#          Flatten-145                  [-1, 768]               0
#          Flatten-146                  [-1, 768]               0
#          Flatten-147                  [-1, 768]               0
#          Flatten-148                  [-1, 768]               0
#          Flatten-149                  [-1, 768]               0
#          Flatten-150                  [-1, 768]               0
#          Flatten-151                  [-1, 768]               0
#          Flatten-152                  [-1, 768]               0
#          Flatten-153                  [-1, 768]               0
#          Flatten-154                  [-1, 768]               0
#          Flatten-155                  [-1, 768]               0
#          Flatten-156                  [-1, 768]               0
#          Flatten-157                  [-1, 768]               0
#          Flatten-158                  [-1, 768]               0
#          Flatten-159                  [-1, 768]               0
#          Flatten-160                  [-1, 768]               0
#          Flatten-161                  [-1, 768]               0
#          Flatten-162                  [-1, 768]               0
#          Flatten-163                  [-1, 768]               0
#          Flatten-164                  [-1, 768]               0
#          Flatten-165                  [-1, 768]               0
#          Flatten-166                  [-1, 768]               0
#          Flatten-167                  [-1, 768]               0
#          Flatten-168                  [-1, 768]               0
#          Flatten-169                  [-1, 768]               0
#          Flatten-170                  [-1, 768]               0
#          Flatten-171                  [-1, 768]               0
#          Flatten-172                  [-1, 768]               0
#          Flatten-173                  [-1, 768]               0
#          Flatten-174                  [-1, 768]               0
#          Flatten-175                  [-1, 768]               0
#          Flatten-176                  [-1, 768]               0
#          Flatten-177                  [-1, 768]               0
#          Flatten-178                  [-1, 768]               0
#          Flatten-179                  [-1, 768]               0
#          Flatten-180                  [-1, 768]               0
#          Flatten-181                  [-1, 768]               0
#          Flatten-182                  [-1, 768]               0
#          Flatten-183                  [-1, 768]               0
#          Flatten-184                  [-1, 768]               0
#          Flatten-185                  [-1, 768]               0
#          Flatten-186                  [-1, 768]               0
#          Flatten-187                  [-1, 768]               0
#          Flatten-188                  [-1, 768]               0
#          Flatten-189                  [-1, 768]               0
#          Flatten-190                  [-1, 768]               0
#          Flatten-191                  [-1, 768]               0
#          Flatten-192                  [-1, 768]               0
#          Flatten-193                  [-1, 768]               0
#          Flatten-194                  [-1, 768]               0
#          Flatten-195                  [-1, 768]               0
#          Flatten-196                  [-1, 768]               0
#           Linear-197                [-1, 1, 30]          23,070
#           Linear-198                [-1, 1, 30]          23,070
#           Linear-199                [-1, 1, 30]          23,070
#           Linear-200                [-1, 1, 30]          23,070
#           Linear-201                [-1, 1, 30]          23,070
#           Linear-202                [-1, 1, 30]          23,070
#           Linear-203                [-1, 1, 30]          23,070
#           Linear-204                [-1, 1, 30]          23,070
#           Linear-205                [-1, 1, 30]          23,070
#           Linear-206                [-1, 1, 30]          23,070
#           Linear-207                [-1, 1, 30]          23,070
#           Linear-208                [-1, 1, 30]          23,070
#           Linear-209                [-1, 1, 30]          23,070
#           Linear-210                [-1, 1, 30]          23,070
#           Linear-211                [-1, 1, 30]          23,070
#           Linear-212                [-1, 1, 30]          23,070
#           Linear-213                [-1, 1, 30]          23,070
#           Linear-214                [-1, 1, 30]          23,070
#           Linear-215                [-1, 1, 30]          23,070
#           Linear-216                [-1, 1, 30]          23,070
#           Linear-217                [-1, 1, 30]          23,070
#           Linear-218                [-1, 1, 30]          23,070
#           Linear-219                [-1, 1, 30]          23,070
#           Linear-220                [-1, 1, 30]          23,070
#           Linear-221                [-1, 1, 30]          23,070
#           Linear-222                [-1, 1, 30]          23,070
#           Linear-223                [-1, 1, 30]          23,070
#           Linear-224                [-1, 1, 30]          23,070
#           Linear-225                [-1, 1, 30]          23,070
#           Linear-226                [-1, 1, 30]          23,070
#           Linear-227                [-1, 1, 30]          23,070
#           Linear-228                [-1, 1, 30]          23,070
#           Linear-229                [-1, 1, 30]          23,070
#           Linear-230                [-1, 1, 30]          23,070
#           Linear-231                [-1, 1, 30]          23,070
#           Linear-232                [-1, 1, 30]          23,070
#           Linear-233                [-1, 1, 30]          23,070
#           Linear-234                [-1, 1, 30]          23,070
#           Linear-235                [-1, 1, 30]          23,070
#           Linear-236                [-1, 1, 30]          23,070
#           Linear-237                [-1, 1, 30]          23,070
#           Linear-238                [-1, 1, 30]          23,070
#           Linear-239                [-1, 1, 30]          23,070
#           Linear-240                [-1, 1, 30]          23,070
#           Linear-241                [-1, 1, 30]          23,070
#           Linear-242                [-1, 1, 30]          23,070
#           Linear-243                [-1, 1, 30]          23,070
#           Linear-244                [-1, 1, 30]          23,070
#           Linear-245                [-1, 1, 30]          23,070
#           Linear-246                [-1, 1, 30]          23,070
#           Linear-247                [-1, 1, 30]          23,070
#           Linear-248                [-1, 1, 30]          23,070
#           Linear-249                [-1, 1, 30]          23,070
#           Linear-250                [-1, 1, 30]          23,070
#           Linear-251                [-1, 1, 30]          23,070
#           Linear-252                [-1, 1, 30]          23,070
#           Linear-253                [-1, 1, 30]          23,070
#           Linear-254                [-1, 1, 30]          23,070
#           Linear-255                [-1, 1, 30]          23,070
#           Linear-256                [-1, 1, 30]          23,070
#           Linear-257                [-1, 1, 30]          23,070
#           Linear-258                [-1, 1, 30]          23,070
#           Linear-259                [-1, 1, 30]          23,070
#           Linear-260                [-1, 1, 30]          23,070
#           Linear-261                [-1, 1, 30]          23,070
#           Linear-262                [-1, 1, 30]          23,070
#           Linear-263                [-1, 1, 30]          23,070
#           Linear-264                [-1, 1, 30]          23,070
#           Linear-265                [-1, 1, 30]          23,070
#           Linear-266                [-1, 1, 30]          23,070
#           Linear-267                [-1, 1, 30]          23,070
#           Linear-268                [-1, 1, 30]          23,070
#           Linear-269                [-1, 1, 30]          23,070
#           Linear-270                [-1, 1, 30]          23,070
#           Linear-271                [-1, 1, 30]          23,070
#           Linear-272                [-1, 1, 30]          23,070
#           Linear-273                [-1, 1, 30]          23,070
#           Linear-274                [-1, 1, 30]          23,070
#           Linear-275                [-1, 1, 30]          23,070
#           Linear-276                [-1, 1, 30]          23,070
#           Linear-277                [-1, 1, 30]          23,070
#           Linear-278                [-1, 1, 30]          23,070
#           Linear-279                [-1, 1, 30]          23,070
#           Linear-280                [-1, 1, 30]          23,070
#           Linear-281                [-1, 1, 30]          23,070
#           Linear-282                [-1, 1, 30]          23,070
#           Linear-283                [-1, 1, 30]          23,070
#           Linear-284                [-1, 1, 30]          23,070
#           Linear-285                [-1, 1, 30]          23,070
#           Linear-286                [-1, 1, 30]          23,070
#           Linear-287                [-1, 1, 30]          23,070
#           Linear-288                [-1, 1, 30]          23,070
#           Linear-289                [-1, 1, 30]          23,070
#           Linear-290                [-1, 1, 30]          23,070
#           Linear-291                [-1, 1, 30]          23,070
#           Linear-292                [-1, 1, 30]          23,070
#           Linear-293                [-1, 1, 30]          23,070
#           Linear-294                [-1, 1, 30]          23,070
#           Linear-295                [-1, 1, 30]          23,070
#           Linear-296                [-1, 1, 30]          23,070
#           Linear-297                [-1, 1, 30]          23,070
#           Linear-298                [-1, 1, 30]          23,070
#           Linear-299                [-1, 1, 30]          23,070
#           Linear-300                [-1, 1, 30]          23,070
#           Linear-301                [-1, 1, 30]          23,070
#           Linear-302                [-1, 1, 30]          23,070
#           Linear-303                [-1, 1, 30]          23,070
#           Linear-304                [-1, 1, 30]          23,070
#           Linear-305                [-1, 1, 30]          23,070
#           Linear-306                [-1, 1, 30]          23,070
#           Linear-307                [-1, 1, 30]          23,070
#           Linear-308                [-1, 1, 30]          23,070
#           Linear-309                [-1, 1, 30]          23,070
#           Linear-310                [-1, 1, 30]          23,070
#           Linear-311                [-1, 1, 30]          23,070
#           Linear-312                [-1, 1, 30]          23,070
#           Linear-313                [-1, 1, 30]          23,070
#           Linear-314                [-1, 1, 30]          23,070
#           Linear-315                [-1, 1, 30]          23,070
#           Linear-316                [-1, 1, 30]          23,070
#           Linear-317                [-1, 1, 30]          23,070
#           Linear-318                [-1, 1, 30]          23,070
#           Linear-319                [-1, 1, 30]          23,070
#           Linear-320                [-1, 1, 30]          23,070
#           Linear-321                [-1, 1, 30]          23,070
#           Linear-322                [-1, 1, 30]          23,070
#           Linear-323                [-1, 1, 30]          23,070
#           Linear-324                [-1, 1, 30]          23,070
#           Linear-325                [-1, 1, 30]          23,070
#           Linear-326                [-1, 1, 30]          23,070
#           Linear-327                [-1, 1, 30]          23,070
#           Linear-328                [-1, 1, 30]          23,070
#           Linear-329                [-1, 1, 30]          23,070
#           Linear-330                [-1, 1, 30]          23,070
#           Linear-331                [-1, 1, 30]          23,070
#           Linear-332                [-1, 1, 30]          23,070
#           Linear-333                [-1, 1, 30]          23,070
#           Linear-334                [-1, 1, 30]          23,070
#           Linear-335                [-1, 1, 30]          23,070
#           Linear-336                [-1, 1, 30]          23,070
#           Linear-337                [-1, 1, 30]          23,070
#           Linear-338                [-1, 1, 30]          23,070
#           Linear-339                [-1, 1, 30]          23,070
#           Linear-340                [-1, 1, 30]          23,070
#           Linear-341                [-1, 1, 30]          23,070
#           Linear-342                [-1, 1, 30]          23,070
#           Linear-343                [-1, 1, 30]          23,070
#           Linear-344                [-1, 1, 30]          23,070
#           Linear-345                [-1, 1, 30]          23,070
#           Linear-346                [-1, 1, 30]          23,070
#           Linear-347                [-1, 1, 30]          23,070
#           Linear-348                [-1, 1, 30]          23,070
#           Linear-349                [-1, 1, 30]          23,070
#           Linear-350                [-1, 1, 30]          23,070
#           Linear-351                [-1, 1, 30]          23,070
#           Linear-352                [-1, 1, 30]          23,070
#           Linear-353                [-1, 1, 30]          23,070
#           Linear-354                [-1, 1, 30]          23,070
#           Linear-355                [-1, 1, 30]          23,070
#           Linear-356                [-1, 1, 30]          23,070
#           Linear-357                [-1, 1, 30]          23,070
#           Linear-358                [-1, 1, 30]          23,070
#           Linear-359                [-1, 1, 30]          23,070
#           Linear-360                [-1, 1, 30]          23,070
#           Linear-361                [-1, 1, 30]          23,070
#           Linear-362                [-1, 1, 30]          23,070
#           Linear-363                [-1, 1, 30]          23,070
#           Linear-364                [-1, 1, 30]          23,070
#           Linear-365                [-1, 1, 30]          23,070
#           Linear-366                [-1, 1, 30]          23,070
#           Linear-367                [-1, 1, 30]          23,070
#           Linear-368                [-1, 1, 30]          23,070
#           Linear-369                [-1, 1, 30]          23,070
#           Linear-370                [-1, 1, 30]          23,070
#           Linear-371                [-1, 1, 30]          23,070
#           Linear-372                [-1, 1, 30]          23,070
#           Linear-373                [-1, 1, 30]          23,070
#           Linear-374                [-1, 1, 30]          23,070
#           Linear-375                [-1, 1, 30]          23,070
#           Linear-376                [-1, 1, 30]          23,070
#           Linear-377                [-1, 1, 30]          23,070
#           Linear-378                [-1, 1, 30]          23,070
#           Linear-379                [-1, 1, 30]          23,070
#           Linear-380                [-1, 1, 30]          23,070
#           Linear-381                [-1, 1, 30]          23,070
#           Linear-382                [-1, 1, 30]          23,070
#           Linear-383                [-1, 1, 30]          23,070
#           Linear-384                [-1, 1, 30]          23,070
#           Linear-385                [-1, 1, 30]          23,070
#           Linear-386                [-1, 1, 30]          23,070
#           Linear-387                [-1, 1, 30]          23,070
#           Linear-388                [-1, 1, 30]          23,070
#           Linear-389                [-1, 1, 30]          23,070
#           Linear-390                [-1, 1, 30]          23,070
#           Linear-391                [-1, 1, 30]          23,070
#           Linear-392                [-1, 1, 30]          23,070
# ================================================================
# Total params: 4,521,720
# Trainable params: 4,521,720
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 1.19
# Params size (MB): 17.25
# Estimated Total Size (MB): 19.02
# ----------------------------------------------------------------

# %%
x = torch.randn(4, 3, 224, 224, requires_grad=True)
pred = patch_embedding(x)
pred.shape
# Out:
# torch.Size([4, 3, 16, 16])
# torch.Size([4, 1, 768])
# torch.Size([4, 1, 30])
# torch.Size([4, 196, 30])
# torch.Size([4, 196, 30])
